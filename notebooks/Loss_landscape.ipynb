# %%
import pylab
# %pylab inline

import tensorflow as tf
tf.enable_eager_execution()
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = tf.cast(y_train, tf.int64), tf.cast(y_test, tf.int64)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
optim = tf.train.AdamOptimizer()
model.compile(optimizer=optim,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# ...
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2239 - acc: 0.9342
# Epoch 2/3
# ...
# 1744/1875 [==========================>...] - ETA: 1s - loss: 0.0998 - acc: 0.9698
# ...
# ...
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0699 - acc: 0.9783

# %%
model.evaluate(x_test, y_test)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step
# [0.06723253657761961, 0.979]

# %%
def get_direction(weights):
    delta = []
    eta = []
    for w in weights:
        d_i = np.random.random_sample(w.shape)
        d_i = (d_i/(np.linalg.norm(d_i) + 1e-10) * np.linalg.norm(w)) 
        t_i = np.random.random_sample(w.shape) 
        t_i = (t_i/(np.linalg.norm(t_i) + 1e-10) * np.linalg.norm(w))
        delta.append(d_i)
        eta.append(t_i)
    return delta, eta

# %%
c = np.random.random_sample((1,10,3,3))
np.linalg.norm(c)
# Out:
# 5.4324466968723195

# %% [markdown]
# rand_direction_delta = []
# for w in model.weights:
#     d_i = np.random.random_sample(w.numpy().shape)
#     d_i = ( d_i/np.sqrt((d_i**2).sum()) ) * np.sqrt((w.numpy()**2).sum())
#     rand_direction_delta.append(d_i)
# rand_direction_eta = []
# for w in model.weights:
#     d_i = np.random.random_sample(w.numpy().shape)
#     d_i = ( d_i/np.sqrt((d_i**2).sum()) ) * np.sqrt((w.numpy()**2).sum())
#     rand_direction_eta.append(d_i)

# %%
theta_star = np.copy(model.get_weights())

# %%
rand_direction_delta, rand_direction_eta = get_direction(theta_star)

# %%
alpha = np.random.random()
model.set_weights(np.array(theta_star) + alpha*np.array(rand_direction_delta))
model.evaluate(x_test, y_test)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step
# [10.527817747497558, 0.3072]

# %%
lands = []
c = 0
tic = time.time()
for alpha in np.linspace(-2, 2, 40): 
    for beta in np.linspace(-2, 2, 40): 
        model.set_weights(np.array(theta_star) + alpha*np.array(rand_direction_delta) + beta*np.array(rand_direction_eta))
        loss = model.evaluate(x_test, y_test, verbose=0)
        lands.append(loss)
        print(c, alpha, beta, loss)
        c+=1
print ('Total time: {}'.format(time.time() - tic))
# Out:
# (0, -2.0, -2.0, [2.3107057388305665, 0.0974])
# (1, -2.0, -1.8974358974358974, [2.3108204292297363, 0.0974])
# (2, -2.0, -1.794871794871795, [2.3109438888549803, 0.0974])
# (3, -2.0, -1.6923076923076923, [2.3110760787963867, 0.0974])
# (4, -2.0, -1.5897435897435899, [2.3112170600891115, 0.0974])
# (5, -2.0, -1.4871794871794872, [2.3113668674468992, 0.0974])
# (6, -2.0, -1.3846153846153846, [2.3115254028320313, 0.0974])
# (7, -2.0, -1.282051282051282, [2.311692844390869, 0.0974])
# (8, -2.0, -1.1794871794871795, [2.311868797302246, 0.0974])
# (9, -2.0, -1.076923076923077, [2.3120535118103027, 0.0974])
# (10, -2.0, -0.9743589743589745, [2.3122469940185546, 0.0974])
# (11, -2.0, -0.8717948717948718, [2.312449292755127, 0.0974])
# (12, -2.0, -0.7692307692307692, [2.3126603218078614, 0.0974])
# (13, -2.0, -0.6666666666666667, [2.31288009185791, 0.0974])
# (14, -2.0, -0.5641025641025641, [2.3131083034515383, 0.0974])
# (15, -2.0, -0.4615384615384617, [2.313345499038696, 0.0974])
# ...

# %%
x = np.linspace(-2, 2, 40)
y = np.linspace(-2, 2, 40)
X, Y = np.meshgrid(x, y)
Z = np.array(lands)[:,0].reshape(40,40)
plt.figure(figsize=(10,10))
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
# Out:
# <a list of 9 text.Text objects>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

# %%
theta = [w.numpy() for w in theta_star]

# %%
model.set_weights(theta_star)
model.evaluate(x_test, y_test)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step
# [0.07171581278820523, 0.9772]

# %%
np.save('loss_land_mnist_4040_-22.npy', [lands])
